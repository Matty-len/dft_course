# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1
# I would proably
# ![image.png](attachment:image.png)
# So basically i can just displace the atoms from each other and find the potential in the adiabatic approximation and find curvature, over sqrt(m) and this is my D
#
# ## 2
# For the generel N atoms, we 3N vibrational modes.
# I would tak every atom and displace it slightly and from there get a potential where i can calculate the curvature in all 3 directions.
