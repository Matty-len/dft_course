# %%
from ase.build import bulk
from gpaw import GPAW, PW

# %%
a = 5.421
si = bulk('Al', 'fcc', a=a)
# or equivalently:
# b = a / 2
# from ase import Atoms
# si = Atoms('Si2', cell=[[0, b, b], [b, 0, b], [b, b, 0]], pbc=True,
#           scaled_positions=[[0, 0, 0], [0.25, 0.25, 0.25]])

for x in [100, 200, 300, 400, 500, 600, 700, 800]:
    # for x in [0.24, 0.22, 0.20, 0.18, 0.16, 0.14, 0.12, 0.1]:
    calc = GPAW(mode=PW(x),
                # h=x,
                xc='PBE',
                kpts=(4, 4, 4),
                txt=f'convergence_{x}.txt')

    si.calc = calc

    print(x, si.get_potential_energy())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0e47309445c3> in <module>
#      17     si.calc = calc
#      18
# ---> 19     print(x, si.get_potential_energy())
#
# ~/dft_venv/ase/ase/atoms.py in get_potential_energy(self, force_consistent, apply_constraint)
#     728                 self, force_consistent=force_consistent)
#     729         else:
# --> 730             energy = self._calc.get_potential_energy(self)
#     731         if apply_constraint:
#     732             for constraint in self.constraints:
#
# ~/dft_venv/ase/ase/calculators/abc.py in get_potential_energy(self, atoms, force_consistent)
#      22         else:
#      23             name = 'energy'
# ---> 24         return self.get_property(name, atoms)
#      25
#      26     def get_potential_energies(self, atoms=None):
#
# ~/dft_venv/ase/ase/calculators/calculator.py in get_property(self, name, atoms, allow_calculation)
#     499                 self.atoms = atoms.copy()
#     500
# --> 501             self.calculate(atoms, [name], system_changes)
#     502
#     503         if name not in self.results:
#
# ~/dft_venv/gpaw/gpaw/calculator.py in calculate(self, atoms, properties, system_changes)
#     369     def calculate(self, atoms=None, properties=['energy'],
#     370                   system_changes=['cell']):
# --> 371         for _ in self.icalculate(atoms, properties, system_changes):
#     372             pass
#     373
#
# ~/dft_venv/gpaw/gpaw/calculator.py in icalculate(self, atoms, properties, system_changes)
#     390                 self.hamiltonian = None
#     391                 self.scf = None
# --> 392                 self.initialize(atoms)
#     393
#     394             self.set_positions(atoms)
#
# ~/dft_venv/gpaw/gpaw/calculator.py in initialize(self, atoms, reading)
#     688         realspace = (mode.name != 'pw' and mode.interpolation != 'fft')
#     689
# --> 690         self.create_setups(mode, xc)
#     691
#     692         if not realspace:
#
# ~/dft_venv/gpaw/gpaw/calculator.py in create_setups(self, mode, xc)
#     951
#     952         Z_a = self.atoms.get_atomic_numbers()
# --> 953         self.setups = Setups(Z_a,
#     954                              self.parameters.setups, self.parameters.basis,
#     955                              xc, filter=filter, world=self.world)
#
# ~/dft_venv/gpaw/gpaw/setup.py in __init__(self, Z_a, setup_types, basis_sets, xc, filter, world)
#    1398                 if isinstance(basis, str):
#    1399                     basis = Basis(symbol, basis, world=world)
# -> 1400                 setup = create_setup(symbol, xc, 2, type,
#    1401                                      basis, setupdata=setupdata,
#    1402                                      filter=filter, world=world)
#
# ~/dft_venv/gpaw/gpaw/setup.py in create_setup(symbol, xc, lmax, type, basis, setupdata, filter, world)
#      97                                  'the %s functional.' % xc.get_setup_name())
#      98         else:
# ---> 99             setupdata = SetupData(symbol, xc.get_setup_name(),
#     100                                   type, True,
#     101                                   world=world)
#
# ~/dft_venv/gpaw/gpaw/setup_data.py in __init__(self, symbol, xcsetupname, name, readxml, zero_reference, world, generator_version)
#     117
#     118         if readxml:
# --> 119             self.read_xml(world=world)
#     120
#     121     def __repr__(self):
#
# ~/dft_venv/gpaw/gpaw/setup_data.py in read_xml(self, source, world)
#     135
#     136     def read_xml(self, source=None, world=None):
# --> 137         PAWXMLParser(self).parse(source=source, world=world)
#     138         nj = len(self.l_j)
#     139         self.e_kin_jj.shape = (nj, nj)
#
# ~/dft_venv/gpaw/gpaw/setup_data.py in parse(self, source, world)
#     450         setup = self.setup
#     451         if source is None:
# --> 452             setup.filename, source = search_for_file(setup.stdfilename, world)
#     453
#     454         setup.fingerprint = hashlib.md5(source).hexdigest()
#
# ~/dft_venv/gpaw/gpaw/setup_data.py in search_for_file(name, world)
#     435 https://wiki.fysik.dtu.dk/gpaw/install.html#install-paw-datasets
#     436 for details."""
# --> 437         raise FileNotFoundError(f'{err}\n{helpful_message}\n')
#     438
#     439     return filename, source
#
# FileNotFoundError: Could not find required PAW dataset file "Al.PBE".
#
# You need to set the GPAW_SETUP_PATH environment variable to point to
# the directories where PAW dataset and basis files are stored.  See
# https://wiki.fysik.dtu.dk/gpaw/install.html#install-paw-datasets
# for details.

# %%
# it kinda converges here as well.
a = 5.421
si = bulk('Al', 'fcc', a=a)
for x in [0.24, 0.22, 0.20, 0.18, 0.16, 0.14, 0.12, 0.1]:
    calc = GPAW(h=x,
                xc='PBE',
                kpts=(4, 4, 4),
                txt=f'convergence_{x}.txt')

    si.calc = calc

    print(x, si.get_potential_energy())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-640fb1697f33> in <module>
#      10     si.calc = calc
#      11
# ---> 12     print(x, si.get_potential_energy())
#
# ~/dft_venv/ase/ase/atoms.py in get_potential_energy(self, force_consistent, apply_constraint)
#     728                 self, force_consistent=force_consistent)
#     729         else:
# --> 730             energy = self._calc.get_potential_energy(self)
#     731         if apply_constraint:
#     732             for constraint in self.constraints:
#
# ~/dft_venv/ase/ase/calculators/abc.py in get_potential_energy(self, atoms, force_consistent)
#      22         else:
#      23             name = 'energy'
# ---> 24         return self.get_property(name, atoms)
#      25
#      26     def get_potential_energies(self, atoms=None):
#
# ~/dft_venv/ase/ase/calculators/calculator.py in get_property(self, name, atoms, allow_calculation)
#     499                 self.atoms = atoms.copy()
#     500
# --> 501             self.calculate(atoms, [name], system_changes)
#     502
#     503         if name not in self.results:
#
# ~/dft_venv/gpaw/gpaw/calculator.py in calculate(self, atoms, properties, system_changes)
#     369     def calculate(self, atoms=None, properties=['energy'],
#     370                   system_changes=['cell']):
# --> 371         for _ in self.icalculate(atoms, properties, system_changes):
#     372             pass
#     373
#
# ~/dft_venv/gpaw/gpaw/calculator.py in icalculate(self, atoms, properties, system_changes)
#     390                 self.hamiltonian = None
#     391                 self.scf = None
# --> 392                 self.initialize(atoms)
#     393
#     394             self.set_positions(atoms)
#
# ~/dft_venv/gpaw/gpaw/calculator.py in initialize(self, atoms, reading)
#     688         realspace = (mode.name != 'pw' and mode.interpolation != 'fft')
#     689
# --> 690         self.create_setups(mode, xc)
#     691
#     692         if not realspace:
#
# ~/dft_venv/gpaw/gpaw/calculator.py in create_setups(self, mode, xc)
#     951
#     952         Z_a = self.atoms.get_atomic_numbers()
# --> 953         self.setups = Setups(Z_a,
#     954                              self.parameters.setups, self.parameters.basis,
#     955                              xc, filter=filter, world=self.world)
#
# ~/dft_venv/gpaw/gpaw/setup.py in __init__(self, Z_a, setup_types, basis_sets, xc, filter, world)
#    1398                 if isinstance(basis, str):
#    1399                     basis = Basis(symbol, basis, world=world)
# -> 1400                 setup = create_setup(symbol, xc, 2, type,
#    1401                                      basis, setupdata=setupdata,
#    1402                                      filter=filter, world=world)
#
# ~/dft_venv/gpaw/gpaw/setup.py in create_setup(symbol, xc, lmax, type, basis, setupdata, filter, world)
#      97                                  'the %s functional.' % xc.get_setup_name())
#      98         else:
# ---> 99             setupdata = SetupData(symbol, xc.get_setup_name(),
#     100                                   type, True,
#     101                                   world=world)
#
# ~/dft_venv/gpaw/gpaw/setup_data.py in __init__(self, symbol, xcsetupname, name, readxml, zero_reference, world, generator_version)
#     117
#     118         if readxml:
# --> 119             self.read_xml(world=world)
#     120
#     121     def __repr__(self):
#
# ~/dft_venv/gpaw/gpaw/setup_data.py in read_xml(self, source, world)
#     135
#     136     def read_xml(self, source=None, world=None):
# --> 137         PAWXMLParser(self).parse(source=source, world=world)
#     138         nj = len(self.l_j)
#     139         self.e_kin_jj.shape = (nj, nj)
#
# ~/dft_venv/gpaw/gpaw/setup_data.py in parse(self, source, world)
#     450         setup = self.setup
#     451         if source is None:
# --> 452             setup.filename, source = search_for_file(setup.stdfilename, world)
#     453
#     454         setup.fingerprint = hashlib.md5(source).hexdigest()
#
# ~/dft_venv/gpaw/gpaw/setup_data.py in search_for_file(name, world)
#     435 https://wiki.fysik.dtu.dk/gpaw/install.html#install-paw-datasets
#     436 for details."""
# --> 437         raise FileNotFoundError(f'{err}\n{helpful_message}\n')
#     438
#     439     return filename, source
#
# FileNotFoundError: Could not find required PAW dataset file "Al.PBE".
#
# You need to set the GPAW_SETUP_PATH environment variable to point to
# the directories where PAW dataset and basis files are stored.  See
# https://wiki.fysik.dtu.dk/gpaw/install.html#install-paw-datasets
# for details.

# %% [markdown]
# image.png

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
